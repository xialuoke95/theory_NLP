# %%
# =============  执行环境 ===================
# === Python 3.7.3
# === tensorflow 2.0.0

# %%
#--------------------- 参考资料
#--------------------- # Step 0: 环境准备
#--------------------- # Step 1: 下载数据并清洗
#--------------------=  Step 2: 定义batch处理函数
#--------------------=  Step 3：构建模型图
#=========================  Step 4: Training
#=========================  Step 5: Plotting
#========================================  See：挑几个词看相近的词；总共有多少个词，多少条训练数据等；
#========================================  实验重跑是否稳定
#========================================  实验embedding只有一个：果然是看embedding到底是以什么目的在学

# %%
import sys
print(sys.executable)
print(tf.__version__)
# Out:
# /Users/zy/Downloads/ENTER/bin/python
# 2.0.0

# %%
#--------------------- 参考资料
# http://www.tensorfly.cn/tfdoc/tutorials/word2vec.html
# https://github.com/jikexueyuanwiki/tensorflow-zh/blob/master/SOURCE/tutorials/word2vec/word2vec_basic.py

# %%
#--------------------- 新老兼容性

#---# py2->py3

urllib = urllib.request
4/3 = int(4 / 3)
xrange = range

# %%
#----# tf 1.9 -> tf 2.0: tf.compat.v1.

tf.placeholder, 
random_uniform, 
GradientDescentOptimizer, 
reduce_sum
tf.session
tf.initialize_all_variables

# %%
#--------------------- 新老兼容性

# %%
#--------------------- # Step 0: 环境准备

from __future__ import print_function
import tensorflow.python.platform

import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import urllib
import zipfile
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

vocabulary_size = 50000

# %%
#--------------------- # Step 0: 环境准备

# %%
# Out:
# <function tensorflow.python.ops.random_ops.random_uniform(shape, minval=0, maxval=None, dtype=tf.float32, seed=None, name=None)>

# %%
#=========================================== Step 1: 下载数据并清洗



# url = 'http://mattmahoney.net/dc/'


# def maybe_download(filename, expected_bytes):
#     """Download a file if not present, and make sure it's the right size."""
#     if not os.path.exists(filename):
#         filename, _ = urllib.request.urlretrieve(url + filename, filename)
#     statinfo = os.stat(filename)
#     if statinfo.st_size == expected_bytes:
#         print('Found and verified', filename)
#     else:
#         print(statinfo.st_size)
#         raise Exception(
#             'Failed to verify ' + filename + '. Can you get to it with a browser?')
#     return filename


# filename = maybe_download('text8.zip', 31344016)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-d98712d1b311> in <module>
#      17
#      18
# ---> 19 filename = maybe_download('text8.zip', 31344016)
#
# <ipython-input-3-d98712d1b311> in maybe_download(filename, expected_bytes)
#       6     """Download a file if not present, and make sure it's the right size."""
#       7     if not os.path.exists(filename):
# ----> 8         filename, _ = urllib.request.urlretrieve(url + filename, filename)
#       9     statinfo = os.stat(filename)
#      10     if statinfo.st_size == expected_bytes:
#
# ~/Downloads/ENTER/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     274
#     275             while True:
# --> 276                 block = fp.read(bs)
#     277                 if not block:
#     278                     break
#
# ~/Downloads/ENTER/lib/python3.7/http/client.py in read(self, amt)
#     445             # Amount is given, implement using readinto
#     446             b = bytearray(amt)
# --> 447             n = self.readinto(b)
#     448             return memoryview(b)[:n].tobytes()
#     449         else:
#
# ~/Downloads/ENTER/lib/python3.7/http/client.py in readinto(self, b)
#     489         # connection, and the user is reading more bytes than will be provided
#     490         # (for example, reading in 1k chunks)
# --> 491         n = self.fp.readinto(b)
#     492         if not n and b:
#     493             # Ideally, we would raise IncompleteRead if the content-length
#
# ~/Downloads/ENTER/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# Read the data into a string.
def read_data(filename):
    f = zipfile.ZipFile(filename)
    for name in f.namelist():
        return f.read(name).split()
    f.close()

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

# %%
filename = "/Users/zy/LearningProjects/theory_NLP/data/text8.zip"
words = read_data(filename)
print('Data size', len(words))
data, count, dictionary, reverse_dictionary = build_dataset(words)
del words  # Hint to reduce memory.
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
# Out:
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], (b'the', 1061396), (b'of', 593677), (b'and', 416629), (b'one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
#=========================  Step 2: 定义batch处理函数

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(int(batch_size / num_skips)):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

# %%
data_index = 0
batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
for i in range(8):
    print(batch[i], '->', labels[i, 0])
    print(reverse_dictionary[batch[i]], '->', reverse_dictionary[labels[i, 0]])
# Out:
# 3081 -> 5234
# b'originated' -> b'anarchism'
# 3081 -> 12
# b'originated' -> b'as'
# 12 -> 6
# b'as' -> b'a'
# 12 -> 3081
# b'as' -> b'originated'
# 6 -> 195
# b'a' -> b'term'
# 6 -> 12
# b'a' -> b'as'
# 195 -> 6
# b'term' -> b'a'
# 195 -> 2
# b'term' -> b'of'

# %%
#=========================  Step 3：构建模型图

batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1       # How many words to consider left and right.
num_skips = 2         # How many times to reuse an input to generate a label.

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64    # Number of negative examples to sample.

# %%
graph = tf.Graph()
with graph.as_default():

    # Input data.
    train_inputs = tf.compat.v1.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.compat.v1.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Construct the variables.
    embeddings = tf.Variable(
        tf.compat.v1.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    nce_weights = tf.Variable(
        tf.compat.v1.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
        tf.nn.nce_loss(nce_weights, nce_biases, train_labels, embed,
                       num_sampled, vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.compat.v1.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.compat.v1.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

# %%
#=========================  Step 4: Training

num_steps = 100001

with tf.compat.v1.Session(graph=graph) as session:
    # We must initialize all variables before we use them.
    tf.compat.v1.initialize_all_variables().run()
    print("Initialized")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to %s:" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  275.98980712890625
# Nearest to b'was': b'streptococcus', b'anatoly', b'avian', b'eikon', b'catastrophes', b'monday', b'eurosceptics', b'disadvantaged',
# Nearest to b'to': b'oswaldo', b'placement', b'transposing', b'introduced', b'royalists', b'landau', b'kharkov', b'plasmids',
# Nearest to b'as': b'headlined', b'implosion', b'pacified', b'violent', b'redundantly', b'vegetable', b'coin', b'whilst',
# Nearest to b'they': b'troupe', b'niccol', b'fairies', b'gotta', b'eloquence', b'ayer', b'singh', b'springsteen',
# Nearest to b'may': b'libertarianism', b'tupolev', b'attached', b'ambrosius', b'misunderstanding', b'abigail', b'treaties', b'anzac',
# Nearest to b'is': b'growths', b'score', b'gish', b'grizzly', b'deoxyribose', b'bakr', b'jscript', b'antisense',
# Nearest to b'system': b'cooking', b'inverted', b'supernatural', b'hydraulic', b'droughts', b'kyle', b'inflate', b'konami',
# Nearest to b'many': b'malice', b'psa', b'groups', b'firewalls', b'unrestrained', b'gaetano', b'hemorrhagic', b'rotational',
# Nearest to b'eight': b'wark', b'compare', b'powerpoint', b'himalayan', b'kingman', b'masturbating', b'agnostic', b'patriot',
# Nearest to b'three': b'porvoo', b'rejuvenated', b'reticent', b'capitulation', b'reverence', b'jehoash', b'in', b'carbons',
# Nearest to b'states': b'park', b'lowercase', b'heijenoort', b'donaldson', b'novoselic', b'alces', b'paymaster', b'saviour',
# Nearest to b'their': b'recalled', b'cited', b'delaunay', b'sargon', b'caribbean', b'fought', b'prose', b'cosmo',
# Nearest to b'other': b'scouting', b'sent', b'hae', b'booty', b'regions', b'kissed', b'marketing', b'ebb',
# Nearest to b'an': b'drilling', b'undergo', b'approximate', b'taxes', b'paralleled', b'healing', b'satirist', b'renunciation',
# Nearest to b'were': b'mascarenhas', b'games', b'notations', b'disjunctive', b'professors', b'alda', b'aspects', b'soluble',
# Nearest to b'up': b'rif', b'cin', b'terribly', b'nasir', b'antiparticles', b'rorty', b'witch', b'waterproof',
# Average loss at step  2000 :  114.39494998550416
# Average loss at step  4000 :  52.7249461145401
# Average loss at step  6000 :  33.752404307842255
# Average loss at step  8000 :  23.555211693286896
# Average loss at step  10000 :  17.173927416443824
# Nearest to b'was': b'is', b'they', b'be', b'sisters', b'natives', b'uc', b'in', b'rho',
# Nearest to b'to': b'in', b'and', b'ipa', b'introduced', b'rho', b'flies', b'zero', b'gladstone',
# Nearest to b'as': b'maradns', b'violent', b'preceding', b'and', b'disc', b'that', UNK, b'authors',
# Nearest to b'they': b'was', b'crawl', b'devoted', b'synonym', b'fairies', b'villages', b'that', b'singh',
# Nearest to b'may': b'dachau', b'mid', b'beautiful', b'march', b'province', b'misunderstanding', b'diphthongs', b'attached',
# Nearest to b'is': b'was', b'are', b'and', b'dect', b'rho', b'mccoy', b'ki', b'be',
# Nearest to b'system': b'situations', b'inverted', b'supernatural', b'hydraulic', b'konami', b'droughts', b'albums', b'describing',
# Nearest to b'many': b'groups', b'psa', b'seeks', b'the', b'ford', b'firewalls', b'arm', b'pet',
# Nearest to b'eight': b'nine', b'zero', b'netbios', b'give', b'cc', b'dragonball', b'compare', b'present',
# Nearest to b'three': b'two', b'rho', b'nine', b'five', b'one', b'fc', b'compression', b'ministerio',
# Nearest to b'states': b'park', b'pet', b'postage', b'lowercase', b'sisters', b'mc', b'e', b'orbs',
# Nearest to b'their': b'the', b'fought', b'lagenorhynchus', b'supervising', b'cited', b'recalled', b'three', b'lunar',
# Nearest to b'other': b'sent', b'regions', b'ching', b'islands', b'marketing', b'lowercase', b'conflicts', b'taiko',
# Nearest to b'an': b'the', b'your', b'orcinus', b'relativity', b'stemming', b'reactor', b'fc', b'latinate',
# Nearest to b'were': b'professors', b'are', b'danger', b'and', b'games', b'rho', b'retain', b'scrambling',
# Nearest to b'up': b'mart', b'toei', b'rho', b'wild', b'portions', b'witch', b'fc', b'elected',
# Average loss at step  12000 :  13.681221597909927
# Average loss at step  14000 :  11.500992062449455
# Average loss at step  16000 :  10.37398533821106
# Average loss at step  18000 :  8.645725484490395
# Average loss at step  20000 :  7.864694233655929
# Nearest to b'was': b'is', b'by', b'eml', b'has', b'be', b'were', b'rho', b'in',
# Nearest to b'to': b'in', b'and', b'ipa', b'for', b'with', b'not', b'patience', b'can',
# Nearest to b'as': b'is', b'by', b'and', b'discogs', b'in', b'maradns', b'violent', b'erg',
# Nearest to b'they': b'he', b'devoted', b'there', b'it', b'crawl', b'that', b'villages', b'fairies',
# Nearest to b'may': b'environmentalists', b'dachau', b'beautiful', b'nine', b'march', b'can', b'six', b'mid',
# Nearest to b'is': b'was', b'are', b'as', b'has', b'eml', b'and', b'be', b'by',
# Nearest to b'system': b'inverted', b'cooking', b'situations', b'kyle', b'hydraulic', b'microscope', b'supernatural', b'konami',
# Nearest to b'many': b'groups', b'patience', b'galatia', b'psa', b'pravda', b'idiom', b'branwell', b'seeks',
# Nearest to b'eight': b'nine', b'zero', b'eml', b'six', b'four', b'five', b'seven', b'two',
# Nearest to b'three': b'two', b'five', b'one', b'four', b'nine', b'zero', b'eight', b'seven',
# Nearest to b'states': b'park', b'eindhoven', b'pet', b'postage', b'mc', b'lowercase', b'hendrix', b'orbs',
# Nearest to b'their': b'the', b'his', b'oxidant', b'lagenorhynchus', b'fought', b'supervising', b'sargon', b'cap',
# Nearest to b'other': b'sent', b'stallman', b'regions', b'ching', b'tuesday', b'marketing', b'lowercase', b'blackmore',
# Nearest to b'an': b'the', b'your', b'orcinus', b'approximate', b'thee', b'satirist', b'relativity', b'destinations',
# Nearest to b'were': b'are', b'was', b'is', b'and', b'professors', b'have', b'widehat', b'emeralds',
# Nearest to b'up': b'mart', b'eml', b'toei', b'spelled', b'jet', b'witch', b'rho', b'wild',
# Average loss at step  22000 :  7.506394190549851
# Average loss at step  24000 :  6.796791507363319
# Average loss at step  26000 :  6.40668771648407
# Average loss at step  28000 :  6.217242048859596
# Average loss at step  30000 :  6.141004899740219
# Nearest to b'was': b'is', b'by', b'were', b'has', b'daigo', b'had', b'be', b'eml',
# Nearest to b'to': b'for', b'ipa', b'can', b'kiang', b'not', b'with', b'in', b'patience',
# Nearest to b'as': b'in', b'by', b'is', b'discogs', b'maradns', b'and', b'unsettled', b'amine',
# Nearest to b'they': b'he', b'there', b'it', b'not', b'she', b'villages', b'devoted', b'rai',
# Nearest to b'may': b'can', b'nine', b'will', b'might', b'dachau', b'beautiful', b'environmentalists', b'should',
# Nearest to b'is': b'was', b'are', b'has', b'eml', b'by', b'be', b'as', b'were',
# Nearest to b'system': b'cooking', b'inverted', b'situations', b'kyle', b'wff', b'konami', b'mauro', b'microscope',
# Nearest to b'many': b'groups', b'patience', b'some', b'pravda', b'galatia', b'those', b'narrators', b'the',
# Nearest to b'eight': b'nine', b'seven', b'five', b'six', b'zero', b'four', b'quagga', b'eml',
# Nearest to b'three': b'four', b'two', b'five', b'seven', b'six', b'eight', b'nine', b'one',
# Nearest to b'states': b'park', b'eindhoven', b'mc', b'pet', b'postage', b'lowercase', b'orbs', b'wff',
# Nearest to b'their': b'the', b'his', b'its', b'a', b'oxidant', b'lagenorhynchus', b'transponder', b'cap',
# Nearest to b'other': b'wff', b'stallman', b'neutronic', b'codomain', b'sent', b'tuesday', b'lowercase', b'regions',
# Nearest to b'an': b'the', b'orcinus', b'drilling', b'your', b'cooh', b'approximate', b'fraud', b'europeans',
# Nearest to b'were': b'are', b'was', b'is', b'have', b'by', b'had', b'professors', b'neutronic',
# Nearest to b'up': b'mart', b'eml', b'cin', b'rif', b'spelled', b'jet', b'toei', b'witch',
# Average loss at step  32000 :  5.824839707136154
# Average loss at step  34000 :  5.686271321296692
# Average loss at step  36000 :  6.123398597478866
# Average loss at step  38000 :  5.485980740904808
# Average loss at step  40000 :  5.448678230166435
# Nearest to b'was': b'is', b'were', b'has', b'had', b'by', b'daigo', b'be', b'eml',
# Nearest to b'to': b'modula', b'for', b'ipa', b'not', b'can', b'patience', b'kiang', b'nine',
# Nearest to b'as': b'and', b'by', b'maradns', b'arctocephalus', b'widehat', b'is', b'discogs', b'modula',
# Nearest to b'they': b'he', b'there', b'it', b'we', b'not', b'she', b'you', b'who',
# Nearest to b'may': b'can', b'might', b'will', b'should', b'to', b'would', b'could', b'dachau',
# Nearest to b'is': b'was', b'are', b'has', b'eml', b'daigo', b'were', b'be', b'as',
# Nearest to b'system': b'inverted', b'cooking', b'kyle', b'konami', b'situations', b'mauro', b'wff', b'supernatural',
# Nearest to b'many': b'some', b'groups', b'these', b'patience', b'other', b'those', b'several', b'the',
# Nearest to b'eight': b'nine', b'seven', b'six', b'five', b'zero', b'four', b'three', b'two',
# Nearest to b'three': b'four', b'two', b'five', b'six', b'seven', b'eight', b'zero', b'one',
# Nearest to b'states': b'park', b'eindhoven', b'pet', b'mc', b'postage', b'saviour', b'lowercase', b'orbs',
# Nearest to b'their': b'his', b'the', b'its', b'cap', b'oxidant', b'her', b'some', b'lagenorhynchus',
# Nearest to b'other': b'many', b'tuesday', b'wff', b'neutronic', b'stallman', b'codomain', b'zilog', b'lowercase',
# Nearest to b'an': b'orcinus', b'drilling', b'the', b'your', b'jewell', b'renunciation', b'bono', b'rnzaf',
# Nearest to b'were': b'are', b'was', b'is', b'have', b'had', b'be', b'and', b'by',
# Nearest to b'up': b'rif', b'mart', b'eml', b'cin', b'spelled', b'terribly', b'toei', b'breeze',
# Average loss at step  42000 :  5.338736907601357
# Average loss at step  44000 :  5.060943979620934
# Average loss at step  46000 :  5.210071475744248
# Average loss at step  48000 :  5.336298958182335
# Average loss at step  50000 :  5.258029188752174
# Nearest to b'was': b'is', b'were', b'has', b'had', b'by', b'daigo', b'be', b'eml',
# Nearest to b'to': b'modula', b'nine', b'zero', b'kiang', b'would', b'eight', b'not', b'will',
# Nearest to b'as': b'stadtbahn', b'arctocephalus', b'widehat', b'and', b'modula', b'szko', b'in', b'amine',
# Nearest to b'they': b'he', b'there', b'it', b'we', b'she', b'not', b'you', b'villages',
# Nearest to b'may': b'can', b'will', b'might', b'would', b'should', b'could', b'nine', b'to',
# Nearest to b'is': b'was', b'are', b'has', b'daigo', b'eml', b'as', b'eight', b'rai',
# Nearest to b'system': b'inverted', b'konami', b'cooking', b'mauro', b'jinshi', b'kyle', b'sisters', b'situations',
# Nearest to b'many': b'some', b'groups', b'these', b'patience', b'other', b'several', b'those', b'gru',
# Nearest to b'eight': b'nine', b'seven', b'six', b'five', b'four', b'zero', b'three', b'sza',
# Nearest to b'three': b'four', b'five', b'six', b'seven', b'two', b'eight', b'nine', b'zero',
# Nearest to b'states': b'park', b'eindhoven', b'pet', b'mc', b'postage', b'saviour', b'gru', b'lowercase',
# Nearest to b'their': b'his', b'its', b'the', b'some', b'her', b'cap', b'huis', b'oxidant',
# Nearest to b'other': b'many', b'neutronic', b'zilog', b'wff', b'codomain', b'these', b'tuesday', b'two',
# Nearest to b'an': b'drilling', b'orcinus', b'europeans', b'approximate', b'the', b'your', b'paralleled', b'renunciation',
# Nearest to b'were': b'are', b'was', b'have', b'had', b'and', b'be', b'by', b'is',
# Nearest to b'up': b'rif', b'nasir', b'eml', b'out', b'breeze', b'mart', b'cin', b'spelled',
# Average loss at step  52000 :  5.237529411196709
# Average loss at step  54000 :  5.072305084824562
# Average loss at step  56000 :  5.098326363563538
# Average loss at step  58000 :  4.843546675920487
# Average loss at step  60000 :  4.942687665224075
# Nearest to b'was': b'is', b'were', b'has', b'had', b'by', b'daigo', b'be', b'after',
# Nearest to b'to': b'would', b'modula', b'can', b'will', b'kiang', b'nine', b'ipa', b'patience',
# Nearest to b'as': b'stadtbahn', b'arctocephalus', b'maradns', b'by', b'galatea', b'when', b'custis', b'widehat',
# Nearest to b'they': b'he', b'there', b'we', b'it', b'she', b'you', b'not', b'who',
# Nearest to b'may': b'can', b'might', b'will', b'would', b'could', b'should', b'cannot', b'beautiful',
# Nearest to b'is': b'was', b'are', b'has', b'eml', b'daigo', b'rai', b'nine', b'be',
# Nearest to b'system': b'inverted', b'konami', b'cooking', b'mauro', b'sisters', b'supernatural', b'jinshi', b'kyle',
# Nearest to b'many': b'some', b'these', b'groups', b'several', b'other', b'patience', b'those', b'both',
# Nearest to b'eight': b'nine', b'seven', b'six', b'five', b'four', b'three', b'zero', b'two',
# Nearest to b'three': b'four', b'five', b'six', b'seven', b'two', b'eight', b'nine', b'one',
# Nearest to b'states': b'park', b'eindhoven', b'saviour', b'sih', b'mc', b'tora', b'postage', b'gru',
# Nearest to b'their': b'his', b'its', b'the', b'her', b'some', b'huis', b'cap', b'oxidant',
# Nearest to b'other': b'many', b'these', b'some', b'neutronic', b'patience', b'wff', b'tuesday', b'zilog',
# Nearest to b'an': b'orcinus', b'drilling', b'renunciation', b'europeans', b'your', b'establishments', b'paralleled', b'bono',
# Nearest to b'were': b'are', b'was', b'have', b'had', b'be', b'by', b'is', b'been',
# Nearest to b'up': b'rif', b'out', b'nasir', b'eml', b'breeze', b'dismiss', b'saxon', b'terribly',
# Average loss at step  62000 :  5.044107585430146
# Average loss at step  64000 :  4.891839460730552
# Average loss at step  66000 :  4.914434793949127
# Average loss at step  68000 :  4.910974691748619
# Average loss at step  70000 :  4.838307540297508
# Nearest to b'was': b'is', b'has', b'had', b'were', b'by', b'daigo', b'be', b'became',
# Nearest to b'to': b'can', b'modula', b'would', b'ebne', b'hyi', b'kiang', b'will', b'patience',
# Nearest to b'as': b'landesverband', b'stadtbahn', b'when', b'arctocephalus', b'in', b'and', b'by', b'modula',
# Nearest to b'they': b'he', b'there', b'we', b'it', b'she', b'you', b'not', b'who',
# Nearest to b'may': b'can', b'will', b'would', b'might', b'could', b'should', b'cannot', b'march',
# Nearest to b'is': b'was', b'are', b'has', b'daigo', b'ebne', b'eml', b'rai', b'hyi',
# Nearest to b'system': b'nuh', b'konami', b'inverted', b'cooking', b'mauro', b'sisters', b'supernatural', b'suitable',
# Nearest to b'many': b'some', b'these', b'several', b'groups', b'other', b'those', b'both', b'patience',
# Nearest to b'eight': b'nine', b'seven', b'six', b'five', b'four', b'three', b'zero', b'landesverband',
# Nearest to b'three': b'four', b'five', b'six', b'seven', b'eight', b'two', b'nine', b'zero',
# Nearest to b'states': b'park', b'hyi', b'eindhoven', b'saviour', b'sih', b'lange', b'tora', b'wacky',
# Nearest to b'their': b'its', b'his', b'the', b'her', b'some', b'hyi', b'huis', b'cap',
# Nearest to b'other': b'many', b'some', b'these', b'patience', b'different', b'wff', b'neutronic', b'zilog',
# Nearest to b'an': b'orcinus', b'drilling', b'europeans', b'establishments', b'darker', b'renunciation', b'your', b'bono',
# Nearest to b'were': b'are', b'was', b'have', b'had', b'be', b'been', b'these', b'include',
# Nearest to b'up': b'rif', b'out', b'down', b'breeze', b'eml', b'pra', b'relapsed', b'saxon',
# Average loss at step  72000 :  4.90435830104351
# Average loss at step  74000 :  4.807388597607613
# Average loss at step  76000 :  4.792209834814072
# Average loss at step  78000 :  4.605620517253875
# Average loss at step  80000 :  4.71421321952343
# Nearest to b'was': b'is', b'were', b'has', b'had', b'by', b'daigo', b'be', b'became',
# Nearest to b'to': b'would', b'can', b'modula', b'ebne', b'will', b'not', b'hyi', b'kiang',
# Nearest to b'as': b'landesverband', b'stadtbahn', b'by', b'maradns', b'modula', b'reply', b'arctocephalus', b'ebne',
# Nearest to b'they': b'he', b'there', b'we', b'you', b'she', b'it', b'who', b'not',
# Nearest to b'may': b'can', b'would', b'will', b'might', b'could', b'should', b'cannot', b'must',
# Nearest to b'is': b'was', b'are', b'has', b'ebne', b'eml', b'daigo', b'be', b'landesverband',
# Nearest to b'system': b'nuh', b'konami', b'inverted', b'cooking', b'mauro', b'sisters', b'suitable', b'hyi',
# Nearest to b'many': b'some', b'several', b'these', b'groups', b'other', b'both', b'those', b'patience',
# Nearest to b'eight': b'seven', b'six', b'five', b'nine', b'four', b'three', b'zero', b'landesverband',
# Nearest to b'three': b'four', b'five', b'six', b'two', b'seven', b'eight', b'one', b'landesverband',
# Nearest to b'states': b'park', b'hyi', b'saviour', b'lange', b'sih', b'eindhoven', b'tora', b'landesverband',
# Nearest to b'their': b'its', b'his', b'the', b'her', b'some', b'hyi', b'huis', b'cap',
# Nearest to b'other': b'many', b'some', b'these', b'different', b'patience', b'neutronic', b'wff', b'churches',
# Nearest to b'an': b'the', b'orcinus', b'europeans', b'paralleled', b'drilling', b'establishments', b'your', b'renunciation',
# Nearest to b'were': b'are', b'was', b'have', b'had', b'be', b'been', b'these', b'hyi',
# Nearest to b'up': b'rif', b'out', b'down', b'relapsed', b'them', b'saxon', b'him', b'eml',
# Average loss at step  82000 :  4.761905717253685
# Average loss at step  84000 :  4.743506404995919
# Average loss at step  86000 :  4.728549705684185
# Average loss at step  88000 :  4.646473987460136
# Average loss at step  90000 :  4.611053771615028
# Nearest to b'was': b'is', b'were', b'had', b'has', b'daigo', b'eight', b'became', b'by',
# Nearest to b'to': b'would', b'nine', b'modula', b'can', b'hyi', b'ebne', b'through', b'kiang',
# Nearest to b'as': b'landesverband', b'stadtbahn', b'by', b'rational', b'widehat', b'szko', b'modula', b'maradns',
# Nearest to b'they': b'he', b'there', b'we', b'you', b'she', b'it', b'who', b'i',
# Nearest to b'may': b'can', b'would', b'will', b'could', b'might', b'should', b'cannot', b'nine',
# Nearest to b'is': b'was', b'has', b'are', b'daigo', b'ebne', b'became', b'eml', b'were',
# Nearest to b'system': b'nuh', b'konami', b'inverted', b'cooking', b'mauro', b'suitable', b'sisters', b'hyi',
# Nearest to b'many': b'some', b'several', b'these', b'groups', b'other', b'those', b'both', b'patience',
# Nearest to b'eight': b'seven', b'nine', b'five', b'six', b'four', b'three', b'landesverband', b'hyi',
# Nearest to b'three': b'four', b'five', b'seven', b'two', b'six', b'eight', b'landesverband', b'hyi',
# Nearest to b'states': b'hyi', b'park', b'lange', b'saviour', b'sih', b'landesverband', b'eindhoven', b'gru',
# Nearest to b'their': b'its', b'his', b'her', b'the', b'some', b'hyi', b'our', b'huis',
# Nearest to b'other': b'many', b'some', b'these', b'different', b'two', b'patience', b'neutronic', b'wff',
# Nearest to b'an': b'riso', b'orcinus', b'paralleled', b'europeans', b'darker', b'daunting', b'renunciation', b'vijayanagara',
# Nearest to b'were': b'are', b'was', b'had', b'have', b'be', b'been', b'these', b'is',
# Nearest to b'up': b'out', b'rif', b'down', b'them', b'him', b'relapsed', b'back', b'saxon',
# Average loss at step  92000 :  4.2860406002998355
# Average loss at step  94000 :  4.501754925966263
# Average loss at step  96000 :  4.43499313557148
# Average loss at step  98000 :  4.5344210780859
# Average loss at step  100000 :  4.580008485674858
# Nearest to b'was': b'is', b'had', b'has', b'were', b'became', b'be', b'daigo', b'ebne',
# Nearest to b'to': b'would', b'can', b'modula', b'ebne', b'will', b'not', b'nine', b'hyi',
# Nearest to b'as': b'landesverband', b'stadtbahn', b'and', b'by', b'cc', b'jeb', b'modula', b'pesce',
# Nearest to b'they': b'he', b'we', b'there', b'you', b'she', b'it', b'who', b'i',
# Nearest to b'may': b'can', b'would', b'will', b'could', b'should', b'might', b'cannot', b'must',
# Nearest to b'is': b'was', b'are', b'has', b'ebne', b'daigo', b'be', b'became', b'eml',
# Nearest to b'system': b'nuh', b'konami', b'mauro', b'inverted', b'suitable', b'cooking', b'sisters', b'hyi',
# Nearest to b'many': b'some', b'several', b'these', b'both', b'other', b'those', b'groups', b'all',
# Nearest to b'eight': b'seven', b'nine', b'six', b'four', b'five', b'three', b'zero', b'landesverband',
# Nearest to b'three': b'four', b'five', b'six', b'seven', b'two', b'eight', b'zero', b'landesverband',
# Nearest to b'states': b'hyi', b'park', b'saviour', b'lange', b'sih', b'kingdom', b'robertson', b'islamism',
# Nearest to b'their': b'its', b'his', b'her', b'the', b'some', b'hyi', b'our', b'huis',
# Nearest to b'other': b'many', b'some', b'these', b'different', b'patience', b'neutronic', b'various', b'churches',
# Nearest to b'an': b'europeans', b'orcinus', b'riso', b'paralleled', b'darker', b'tydings', b'renunciation', b'establishments',
# Nearest to b'were': b'are', b'was', b'have', b'had', b'be', b'these', b'is', b'been',
# Nearest to b'up': b'out', b'rif', b'down', b'them', b'him', b'back', b'place', b'relapsed',

# %%
#=========================  Step 5: Plotting

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

    plt.savefig(filename)

# %%
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
plot_only = 500
low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
labels = list(dictionary.keys())[:plot_only]
plot_with_labels(low_dim_embs, labels)

# %%
#========================================  See：挑几个词看相近的词；总共有多少个词，多少条训练数据等；

# %%
#========================================  实验重跑是否稳定
graph = tf.Graph()
with graph.as_default():

    # Input data.
    train_inputs = tf.compat.v1.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.compat.v1.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Construct the variables.
    embeddings = tf.Variable(
        tf.compat.v1.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    nce_weights = tf.Variable(
        tf.compat.v1.truncated_normal([vocabulary_size, embedding_size],
                            stddev=1.0 / math.sqrt(embedding_size)))
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
        tf.nn.nce_loss(nce_weights, nce_biases, train_labels, embed,
                       num_sampled, vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.compat.v1.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.compat.v1.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

# %%
graph

# %%
#========================================  实验embedding只有一个：果然是看embedding到底是以什么目的在学
graph_one_emb = tf.Graph()
with graph_one_emb.as_default():

    # Input data.
    train_inputs = tf.compat.v1.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.compat.v1.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Construct the variables.
    embeddings = tf.Variable(
        tf.compat.v1.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    nce_weights = embeddings
    nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_inputs)

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    loss = tf.reduce_mean(
        tf.nn.nce_loss(nce_weights, nce_biases, train_labels, embed,
                       num_sampled, vocabulary_size))

    # Construct the SGD optimizer using a learning rate of 1.0.
    optimizer = tf.compat.v1.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all embeddings.
    norm = tf.sqrt(tf.compat.v1.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

# %%
num_steps = 100001

with tf.compat.v1.Session(graph=graph_one_emb) as session:
    # We must initialize all variables before we use them.
    tf.compat.v1.initialize_all_variables().run()
    print("Initialized")

    average_loss = 0
    for step in range(num_steps):
        batch_inputs, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val

        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print("Average loss at step ", step, ": ", average_loss)
            average_loss = 0

        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log_str = "Nearest to %s:" % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = "%s %s," % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  312.5035400390625
# Nearest to b'was': b'intermission', b'operations', b'histological', b'disenchanted', b'wasted', b'webcams', b'toole', b'meissen',
# Nearest to b'to': b'depicted', b'creasy', b'prosecutors', b'hoisted', b'mayhem', b'outrageous', b'styling', b'authoring',
# Nearest to b'as': b'pataki', b'pharmaceutical', b'anaesthesia', b'archduke', b'occasionally', b'gymnasium', b'length', b'valerius',
# Nearest to b'they': b'universals', b'offal', b'panic', b'stitches', b'sten', b'doves', b'pursues', b'economically',
# Nearest to b'may': b'marquis', b'headlights', b'destructive', b'baird', b'carolla', b'publication', b'herbivores', b'profitable',
# Nearest to b'is': b'corneille', b'chicagoans', b'circumstances', b'tenant', b'demonstrably', b'headache', b'ingres', b'soci',
# Nearest to b'system': b'confucianism', b'minimise', b'gauze', b'suebi', b'lebanese', b'lathe', b'federko', b'brac',
# Nearest to b'many': b'existing', b'standstill', b'algorithms', b'recount', b'garonne', b'accident', b'jacquard', b'object',
# Nearest to b'eight': b'jost', b'pitch', b'literal', b'heartbeat', b'reginae', b'kahn', b'stressful', b'spree',
# Nearest to b'three': b'fontane', b'improving', b'chevy', b'wasteful', b'campo', b'nests', b'rabbit', b'revolve',
# Nearest to b'states': b'tombs', b'biographer', b'electrolytes', b'unoccupied', b'gagauz', b'suffers', b'uncomplicated', b'ricky',
# Nearest to b'their': b'celluloid', b'deceiving', b'ipc', b'austerity', b'soup', b'superstition', b'clyde', b'torquay',
# Nearest to b'other': b'aegina', b'norwegians', b'cobol', b'espionage', b'sh', b'freeware', b'relapse', b'sentries',
# Nearest to b'an': b'krahn', b'mediation', b'endowments', b'loosely', b'panthers', b'leszek', b'demonstrates', b'describes',
# Nearest to b'were': b'lyra', b'bloomfield', b'cyanobacteria', b'embroidered', b'subverted', b'alphabetically', b'hispano', b'commutativity',
# Nearest to b'up': b'crowns', b'bulletin', b'mineralogist', b'mordant', b'stargate', b'charlottenburg', b'scarcity', b'jason',
# Average loss at step  2000 :  164.97634477615355
# Average loss at step  4000 :  105.9147721004486
# Average loss at step  6000 :  81.92400886821747
# Average loss at step  8000 :  67.56408889198303
# Average loss at step  10000 :  57.611836684703825
# Nearest to b'was': b'it', b'by', b'that', b'this', b'first', b'later', UNK, b'being',
# Nearest to b'to': UNK, b'in', b'being', b'a', b'an', b'the', b'after', b'of',
# Nearest to b'as': b'after', b'many', b'well', b'such', b'a', b'but', b'about', b'known',
# Nearest to b'they': b'have', b'but', b'as', b'are', b'use', b'binding', b'however', b'after',
# Nearest to b'may': b'be', b'have', b'can', b'part', b'also', b'used', b'made', b'more',
# Nearest to b'is': b'it', b'not', b'this', b'has', b'that', b'but', b'known', b'more',
# Nearest to b'system': b'year', b'major', b'name', b'said', b'there', b'his', b'external', b'not',
# Nearest to b'many': b'as', b'other', b'but', b'well', b'however', b'has', b'binding', b'no',
# Nearest to b'eight': b'six', b'one', b'nine', b'three', b'two', b'five', b'into', b'four',
# Nearest to b'three': b'four', b'five', b'nine', b'six', b'two', b'one', b'years', b'about',
# Nearest to b'states': b'united', b'until', b'also', UNK, b'very', b'number', b'born', b'modern',
# Nearest to b'their': b'first', b'during', b'made', b'many', b'his', b'this', b'with', b'them',
# Nearest to b'other': b'many', b'three', b'binding', b'about', b'or', b'form', b'no', b'all',
# Nearest to b'an': b'as', b'to', UNK, b'from', b'a', b'many', b'has', b'had',
# Nearest to b'were': b'for', b'about', b'but', b'as', b'used', b'first', b'during', b'after',
# Nearest to b'up': b'with', b'number', b'no', b'later', b'one', b'or', b'in', b'part',
# Average loss at step  12000 :  47.4061959733963
# Average loss at step  14000 :  42.71931491041183
# Average loss at step  16000 :  67.38013319730759
# Average loss at step  18000 :  270.3548311896324
# Average loss at step  20000 :  101.20393886756897
# Nearest to b'was': b'its', b'story', b'able', b'it', b'as', b'from', b'after', b'time',
# Nearest to b'to': b'and', b'a', b'be', b'or', b'third', b'that', b'its', b'provide',
# Nearest to b'as': b'is', b'it', b'by', b'also', b'and', b'or', b'with', b'are',
# Nearest to b'they': b'often', b'are', b'only', b'made', b'able', b'not', b'also', b'time',
# Nearest to b'may': b'which', b'only', b'be', b'also', b'that', b'each', b'have', b'following',
# Nearest to b'is': b'this', b'that', b'a', b'it', b'only', b'as', b'not', b'work',
# Nearest to b'system': b'are', b'has', b'that', b'its', b'red', b'other', b'as', b'all',
# Nearest to b'many': b'other', b'or', b'like', b'that', b'won', b'most', b'from', b'as',
# Nearest to b'eight': b'seven', b'five', b'three', b'four', b'six', b'one', b'nine', b'zero',
# Nearest to b'three': b'six', b'two', b'zero', b'four', b'seven', b'five', b'eight', b'th',
# Nearest to b'states': b'united', b'that', b'from', b'wrote', b'claude', b'article', b'will', b'become',
# Nearest to b'their': b'more', b'into', b'made', b'its', b'it', b'on', b'other', b'able',
# Nearest to b'other': b'from', b'most', b'for', b'a', b'its', b'also', b'that', b'with',
# Nearest to b'an': b'a', b'this', b'is', b'any', b'provide', b'has', b'or', b'of',
# Nearest to b'were': b'any', b'including', b'these', b'when', b'used', b'before', b'on', b'not',
# Nearest to b'up': b'has', b'it', b'by', b'development', b'number', b'see', b'kofi', b'sound',
# Average loss at step  22000 :  65.06933527565002
# Average loss at step  24000 :  51.65887267923355
# Average loss at step  26000 :  37.84289254450798
# Average loss at step  28000 :  32.091875838041304
# Average loss at step  30000 :  26.927727110862733
# Nearest to b'was': b'it', b'a', b'and', b'by', UNK, b'for', b'in', b'were',
# Nearest to b'to': b'a', b'its', b'find', b'established', b're', b'themselves', b'may', b'an',
# Nearest to b'as': b'a', b'an', b'known', b'called', b'it', b'its', b'established', b'to',
# Nearest to b'they': b'were', b'it', b'that', b'which', b'now', b'was', b'had', b'could',
# Nearest to b'may': b'thus', b'would', b'also', b'where', b'to', b'a', b'have', b'should',
# Nearest to b'is': b'it', b'also', b'which', b'for', b'now', b'there', b'a', b'where',
# Nearest to b'system': b'any', b'through', b'while', b'other', b'however', b'available', b'process', b'including',
# Nearest to b'many': b'through', b'other', b'however', b's', b'became', b'a', b'large', b'although',
# Nearest to b'eight': b'three', b'four', b'six', b'five', b'two', b'december', b'one', b'seven',
# Nearest to b'three': b'eight', b'four', b'six', b'five', b'one', b'seven', b'two', b'december',
# Nearest to b'states': b'united', b'member', b'during', b'kingdom', b'all', b'major', b'given', b'central',
# Nearest to b'their': b'her', b'permanent', b'external', b'attempted', b'widespread', b'huge', b'comics', b'months',
# Nearest to b'other': b'through', b'available', b'many', b'number', b'countries', b'part', b'functions', b'no',
# Nearest to b'an': b'its', b'a', b'it', b'with', b'as', b'to', b'also', b'on',
# Nearest to b'were': b'they', b'it', b'who', b'which', b'by', b'on', b'there', b'was',
# Nearest to b'up': b'radiohead', b'pawns', b'bureaucrat', b'nicopolis', b'haight', b'veil', b'resorts', b'ayya',
# Average loss at step  32000 :  25.10732804250717
# Average loss at step  34000 :  24.709905042171478
# Average loss at step  36000 :  21.764599106550218
# Average loss at step  38000 :  22.8167005341053
# Average loss at step  40000 :  19.861950699567796
# Nearest to b'was': b'she', b'which', b'but', b'a', b'is', b'that', b'then', b'he',
# Nearest to b'to': b'began', b'and', b'a', b'the', b'itself', b'have', b'was', b'then',
# Nearest to b'as': b'a', b'well', b'an', b'known', b'originally', b'was', b'being', b'seen',
# Nearest to b'they': b'were', b'would', b'said', b'she', b'have', b'found', b'only', b'there',
# Nearest to b'may': b'through', b'day', b'home', b'germany', b'formed', b'thought', b'date', b'it',
# Nearest to b'is': b'was', b'but', b'a', b'it', b'that', b'now', b'she', b'only',
# Nearest to b'system': b'into', b'traditional', b'laws', b'end', b'other', b'education', b'towards', b'an',
# Nearest to b'many': b'some', b'by', b'major', b'countries', b'various', b'others', b'cases', b'several',
# Nearest to b'eight': b'seven', b'one', b'three', b'four', b'five', b'six', b'nine', b'two',
# Nearest to b'three': b'six', b'four', b'eight', b'five', b'seven', b'one', b'zero', b'two',
# Nearest to b'states': b'united', b'kingdom', b'nations', b'european', b'economy', b'many', b'several', b'practice',
# Nearest to b'their': b'any', b'date', b'its', b'after', b'single', b'up', b'by', b'some',
# Nearest to b'other': b'each', b'example', b'major', b'from', b'traditional', b'because', b'within', b'for',
# Nearest to b'an': b'as', b'a', b'for', b'became', b'was', b'within', b'associated', b'major',
# Nearest to b'were': b'they', b'originally', b'replaced', b'she', b'only', b'that', b'being', b'used',
# Nearest to b'up': b'make', b'set', b'making', b'which', b'made', b'remained', b'then', b'working',
# Average loss at step  42000 :  19.56375516605377
# Average loss at step  44000 :  17.92032269859314
# Average loss at step  46000 :  16.762078660726548
# Average loss at step  48000 :  21.99882440185547
# Average loss at step  50000 :  18.612657942295076
# Nearest to b'was': b'it', b'therefore', b'probably', b'killed', b'built', b'which', b'introduced', b'given',
# Nearest to b'to': b'create', b'be', b'began', b'according', b'refers', b'only', b'return', b'said',
# Nearest to b'as': b'known', b'well', b'such', b'an', b'served', b'built', b'seen', b'described',
# Nearest to b'they': b'were', b'given', b'but', b'which', b'have', b'produced', b'that', b'there',
# Nearest to b'may': b'be', b'usually', b'take', b'can', b'not', b'began', b'only', b'probably',
# Nearest to b'is': b'it', b'what', b'which', b'said', b'typically', b'used', b'itself', b'this',
# Nearest to b'system': b'conditions', b'complete', b'when', b'long', b'team', b'images', b'also', b'composed',
# Nearest to b'many': b'different', b'some', b'these', b'modern', b'among', b'cases', b'however', b'ashley',
# Nearest to b'eight': b'four', b'seven', b'one', b'nine', b'five', b'three', b'six', b'two',
# Nearest to b'three': b'eight', b'four', b'five', b'six', b'one', b'two', b'nine', b'seven',
# Nearest to b'states': b'united', b'nations', b'kingdom', b'forces', b'army', b'by', b'next', b'australia',
# Nearest to b'their': b'both', b'foreign', b'home', b'party', b'number', b'still', b'most', b'by',
# Nearest to b'other': b'control', b'many', b'problems', b'some', b'early', b'because', b'art', b'success',
# Nearest to b'an': b'as', b'however', b'particularly', b'received', b'some', b'complex', b'question', b'using',
# Nearest to b'were': b'they', b'so', b'by', b'mainly', b'enough', b'built', b'difficult', b'which',
# Nearest to b'up': b'set', b'to', b'back', b'making', b'play', b'way', b'them', b'began',
# Average loss at step  52000 :  15.439244038820267
# Average loss at step  54000 :  14.62746859383583
# Average loss at step  56000 :  13.392343344688415
# Average loss at step  58000 :  1262.356532198429
# Average loss at step  60000 :  168.48458605718614
# Nearest to b'was': b'he', b'there', b'they', b'time', b'is', b'a', b'in', b'also',
# Nearest to b'to': b'be', b'but', b'his', b'a', b'with', b'was', b'in', b'how',
# Nearest to b'as': b'the', b'that', b'having', b'only', b'but', b'a', b'these', b'not',
# Nearest to b'they': b'there', b'was', b'were', b'also', b'are', b'is', b'had', b'has',
# Nearest to b'may': b'will', b'believed', b'have', b'studied', b'be', b'still', b'base', b'also',
# Nearest to b'is': b'also', b'are', b'there', b'was', b'which', b'that', b'they', b'has',
# Nearest to b'system': b'body', b'in', b'many', b'his', b'of', b'japanese', b'first', b'most',
# Nearest to b'many': b'most', b'for', b'his', b'are', b'their', b'also', b'but', b'which',
# Nearest to b'eight': b'six', b'four', b'three', b'five', b'seven', b'one', b'nine', b'two',
# Nearest to b'three': b'six', b'four', b'nine', b'one', b'eight', b'five', b'seven', b'zero',
# Nearest to b'states': b'all', b'united', b'nations', b'state', b'put', b'during', b'uk', b'killed',
# Nearest to b'their': b'many', b'for', b'time', b'after', b'was', b'his', b'all', b'and',
# Nearest to b'other': b'most', b'many', b'of', b'in', b'which', b'at', b'the', b'his',
# Nearest to b'an': b'with', b'was', b'a', b'there', b'for', b'while', b'all', b'is',
# Nearest to b'were': b'they', b'that', b'there', b'killed', b'also', b'having', b'being', b'has',
# Nearest to b'up': b'make', b'into', b'organized', b'had', b'an', b'taken', b'break', b'gave',
# Average loss at step  62000 :  104.09287568521499
# Average loss at step  64000 :  59.6760505900383
# Average loss at step  66000 :  55.774195247888564
# Average loss at step  68000 :  50.75607591342926
# Average loss at step  70000 :  36.18771583127975
# Nearest to b'was': b'made', b'which', b'when', b'it', b'this', b'for', b'by', b'at',
# Nearest to b'to': b'this', b'which', b'with', b'for', b'put', b'use', b'was', b'together',
# Nearest to b'as': b'such', b'known', b'well', b'a', b'are', b'for', b'having', b'far',
# Nearest to b'they': b'were', b'that', b'would', b'found', b'however', b'are', b'have', b'only',
# Nearest to b'may': b'all', b'be', b'will', b'these', b'according', b'like', b'have', b'said',
# Nearest to b'is': b'built', b'that', b'though', b'still', b'described', b'which', b'since', b'information',
# Nearest to b'system': b'however', b'because', b'among', b'a', b'form', b'title', b'number', b'within',
# Nearest to b'many': b'part', b'use', b'other', b'for', b'first', b'this', b'a', b'with',
# Nearest to b'eight': b'five', b'seven', b'six', b'three', b'four', b'september', b'nine', b'two',
# Nearest to b'three': b'nine', b'four', b'six', b'two', b'seven', b'five', b'zero', b'one',
# Nearest to b'states': b'united', b'kingdom', b'nations', b'since', b'under', UNK, b'army', b'title',
# Nearest to b'their': b'works', b'own', b'way', b'society', b'arms', b'expansion', b'name', b'down',
# Nearest to b'other': b'law', b'most', b'its', b'many', b'among', b'names', b'several', b'in',
# Nearest to b'an': b'very', b'conditions', b'now', b'probably', b'office', b'police', b'popular', b'methods',
# Nearest to b'were': b'they', b'are', b'who', b'sometimes', b'that', b'introduced', b'which', b'exist',
# Nearest to b'up': b'to', b'according', b'made', b'use', b'force', b'this', b'for', b'put',
# Average loss at step  72000 :  39.37004037308693
# Average loss at step  74000 :  37.02149300527573
# Average loss at step  76000 :  31.479375361442568
# Average loss at step  78000 :  27.303595646858216
# Average loss at step  80000 :  26.106602825403215
# Nearest to b'was': b'built', b'is', b'when', b'but', b'claimed', b'that', b'placed', b'were',
# Nearest to b'to': b'due', b'moved', b'provide', b'find', b'leave', b'lead', b'needed', b'refused',
# Nearest to b'as': b'such', b'well', b'known', b'an', b'a', b'for', b'used', b'having',
# Nearest to b'they': b'are', b'were', b'not', b'can', b'though', b'that', b'what', b'say',
# Nearest to b'may': b'be', b'can', b'not', b'would', b'might', b'we', b'found', b'say',
# Nearest to b'is': b'but', b'which', b'became', b'was', b'killed', b'when', b'considered', b'sometimes',
# Nearest to b'system': b'operating', b'while', b'using', b'is', b'names', b'features', b'technology', b'but',
# Nearest to b'many': b'some', b'other', b'several', b'among', b'most', b'others', b'for', b'terms',
# Nearest to b'eight': b'seven', b'three', b'four', b'two', b'six', b'nine', b'zero', b'august',
# Nearest to b'three': b'two', b'seven', b'six', b'eight', b'zero', b'nine', b'four', b'isbn',
# Nearest to b'states': b'united', b'kingdom', b'nations', b'constitution', b'senate', b'in', b'under', b'while',
# Nearest to b'their': b'its', b'in', b'first', b'body', b'own', b'with', b'future', b'her',
# Nearest to b'other': b'many', b'for', b'among', b'another', b'in', b'several', b'some', b'certain',
# Nearest to b'an': b'for', b'as', b'another', b'with', b'remains', b'other', b'single', b'failed',
# Nearest to b'were': b'killed', b'they', b'are', b'there', b'that', b'which', b'but', b'sometimes',
# Nearest to b'up': b'came', b'into', b'led', b'way', b'work', b'back', b'about', b'run',
# Average loss at step  82000 :  21.57507375073433
# Average loss at step  84000 :  22.411915213823317
# Average loss at step  86000 :  21.010765422105788
# Average loss at step  88000 :  17.838161413431166
# Average loss at step  90000 :  19.925656072616576
# Nearest to b'was': b'it', b'is', b'he', b'again', b'made', b'originally', b'has', b'actually',
# Nearest to b'to': b'back', b'describe', b'returned', b'turn', b'going', b'make', b'due', b'according',
# Nearest to b'as': b'known', b'such', b'well', b'a', b'defined', b'now', b'follows', b'became',
# Nearest to b'they': b'that', b'there', b'are', b'were', b'but', b'actually', b'claimed', b'said',
# Nearest to b'may': b'found', b'appear', b'be', b'can', b'leave', b'make', b'done', b'to',
# Nearest to b'is': b'it', b'currently', b'became', b'held', b'also', b'which', b'but', b'now',
# Nearest to b'system': b'using', b'purpose', b'legal', b'situation', b'for', b'feature', b'limited', b'strong',
# Nearest to b'many': b'several', b'places', b'modern', b'various', b'people', b'however', b'works', b'fields',
# Nearest to b'eight': b'five', b'four', b'three', b'seven', b'km', b'two', b'zero', b'august',
# Nearest to b'three': b'five', b'zero', b'two', b'eight', b'about', b'approximately', b'seven', b'km',
# Nearest to b'states': b'united', b'kingdom', b'nations', b'member', b'constitution', b'government', b'canada', b'under',
# Nearest to b'their': b'own', b'taking', b'use', b'all', b'extensive', b'face', b'mls', b'her',
# Nearest to b'other': b'including', b'places', b'various', b'changes', b'older', b'some', b'countries', b'companies',
# Nearest to b'an': b'mostly', b'successful', b'with', b'became', b'controlled', b'remained', b'mls', b'performance',
# Nearest to b'were': b'held', b'there', b'they', b'produced', b'developed', b'also', b'shown', b'ever',
# Nearest to b'up': b'came', b'way', b'make', b'him', b'gave', b'give', b'run', b'put',
# Average loss at step  92000 :  20.246778673648834
# Average loss at step  94000 :  20.148491583108903
# Average loss at step  96000 :  16.53372545170784
# Average loss at step  98000 :  18.89312630081177
# Average loss at step  100000 :  15.65464089155197
# Nearest to b'was': b'he', b'created', b'it', b'formed', b'which', b'killed', b'made', b'changed',
# Nearest to b'to': b'due', b'prior', b'give', b'according', b'returned', b'find', b'moved', b'make',
# Nearest to b'as': b'well', b'such', b'defined', b'known', b'seen', b'follows', b'described', b'established',
# Nearest to b'they': b'were', b'what', b'are', b'claimed', b'it', b'there', b'had', b'could',
# Nearest to b'may': b'have', b'should', b'would', b'will', b'must', b'shown', b'can', b'could',
# Nearest to b'is': b'it', b'supported', b'now', b'used', b'held', b'placed', b'actually', b'generally',
# Nearest to b'system': b'remains', b'using', b'process', b'market', b'composed', b'illustrating', b'case', b'which',
# Nearest to b'many': b'other', b'cases', b'older', b'countries', b'some', b'places', b'various', b'changes',
# Nearest to b'eight': b'one', b'six', b'seven', b'nine', b'three', b'four', b'five', b'two',
# Nearest to b'three': b'five', b'six', b'four', b'seven', b'one', b'eight', b'two', b'nine',
# Nearest to b'states': b'united', b'kingdom', b'nations', b'constitution', b'state', b'senate', b'us', b'that',
# Nearest to b'their': b'its', b'his', b'fame', b'attention', b'own', b'minimization', b'despite', b'work',
# Nearest to b'other': b'various', b'each', b'many', b'versions', b'unlike', b'places', b'parts', b'older',
# Nearest to b'an': b'with', b'extensive', b'granary', b'methionine', b'individual', b'illustrating', b'similarly', b'hays',
# Nearest to b'were': b'they', b'are', b'held', b'changed', b'developed', b'killed', b'placed', b'had',
# Nearest to b'up': b'set', b'him', b'to', b'put', b'make', b'turn', b'them', b'made',

# %%
#========================================   nce_loss怎么拆解: 干了啥

# %%
#========================================  模型图讲解
